# %% [markdown]
# <a href="https://colab.research.google.com/github/hanghae-plus-AI/AI-1-gwkcareer/blob/main/week6/run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/sample_data')

# %%
# !pip install datasets evaluate transformers

# %%
# !pip install wandb

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: gwkcareer (gwkcareer-hanghae). Use `wandb login --relogin` to force relogin

# %%
import os
os.system("python train.py --model_name_or_path openai-community/openai-gpt --per_device_train_batch_size 8 --dataset_name wikitext --dataset_config_name wikitext-2-raw-v1 --do_train --output_dir /tmp/test-clm --save_total_limit 1 --logging_steps 100")
# Out:
# 35072
